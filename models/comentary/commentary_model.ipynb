# %% [markdown]
# # Libraries

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Dataset

# %%
df = pd.read_csv('../../src/data/comments.csv')

# %%
df
# Out:
#                                                      url  id_game  time  \
# 0      https://www.foxsports.com./soccer/boxscore?id=...        0     0
# 1      https://www.foxsports.com./soccer/boxscore?id=...        0     0
# 2      https://www.foxsports.com./soccer/boxscore?id=...        0     0
# 3      https://www.foxsports.com./soccer/boxscore?id=...        0     1
# 4      https://www.foxsports.com./soccer/boxscore?id=...        0     2
# ...                                                  ...      ...   ...
# 14636  https://www.foxsports.com./soccer/boxscore?id=...      233    41
# 14637  https://www.foxsports.com./soccer/boxscore?id=...      233    43
# 14638  https://www.foxsports.com./soccer/boxscore?id=...      233    43
# 14639  https://www.foxsports.com./soccer/boxscore?id=...      233    44
# 14640  https://www.foxsports.com./soccer/boxscore?id=...      233    45
#
#                      team                                               comm
# 0           Bayern Munich                      The current period has begun.
# 1           Bayern Munich  Free kick for FC Bayern Munich in their own half.
# 2           Bayern Munich  Can FC Bayern Munich get the ball into an atta...
# 3           Bayern Munich  Harm Osmers signals a FC Bayern Munich throw-i...
# 4       Hertha BSC Berlin   Hertha BSC awarded a throw-in in their own half.
# ...                   ...                                                ...
# 14636        SC Paderborn                         Free kick SC Paderborn 07.
# 14637        SC Paderborn  The match has been stopped briefly for attenti...
# 14638        SC Paderborn  Klaus Gjasula returns to the field for SC Pade...
# 14639  Fortuna Düsseldorf  Free kick for Fortuna Dusseldorf in their own ...
# 14640  Fortuna Düsseldorf                      The current period has ended.
#
# [14641 rows x 5 columns]

# %% [markdown]
# # Natual Language Processing - dealing with text data

# %%
#Taking a sample to test

id0 = df[(df['id_game'] == 0)]

# %%
id0.head()
# Out:
#                                                  url  id_game  time  \
# 0  https://www.foxsports.com./soccer/boxscore?id=...        0     0
# 1  https://www.foxsports.com./soccer/boxscore?id=...        0     0
# 2  https://www.foxsports.com./soccer/boxscore?id=...        0     0
# 3  https://www.foxsports.com./soccer/boxscore?id=...        0     1
# 4  https://www.foxsports.com./soccer/boxscore?id=...        0     2
#
#                 team                                               comm
# 0      Bayern Munich                      The current period has begun.
# 1      Bayern Munich  Free kick for FC Bayern Munich in their own half.
# 2      Bayern Munich  Can FC Bayern Munich get the ball into an atta...
# 3      Bayern Munich  Harm Osmers signals a FC Bayern Munich throw-i...
# 4  Hertha BSC Berlin   Hertha BSC awarded a throw-in in their own half.

# %%
id0
# Out:
#                                                   url  id_game  time  \
# 0   https://www.foxsports.com./soccer/boxscore?id=...        0     0
# 1   https://www.foxsports.com./soccer/boxscore?id=...        0     0
# 2   https://www.foxsports.com./soccer/boxscore?id=...        0     0
# 3   https://www.foxsports.com./soccer/boxscore?id=...        0     1
# 4   https://www.foxsports.com./soccer/boxscore?id=...        0     2
# 5   https://www.foxsports.com./soccer/boxscore?id=...        0     3
# 6   https://www.foxsports.com./soccer/boxscore?id=...        0     3
# 7   https://www.foxsports.com./soccer/boxscore?id=...        0     5
# 8   https://www.foxsports.com./soccer/boxscore?id=...        0     5
# 9   https://www.foxsports.com./soccer/boxscore?id=...        0     7
# 10  https://www.foxsports.com./soccer/boxscore?id=...        0     7
# 11  https://www.foxsports.com./soccer/boxscore?id=...        0     8
# 12  https://www.foxsports.com./soccer/boxscore?id=...        0     8
# 13  https://www.foxsports.com./soccer/boxscore?id=...        0     9
# 14  https://www.foxsports.com./soccer/boxscore?id=...        0    10
# 15  https://www.foxsports.com./soccer/boxscore?id=...        0    10
# 16  https://www.foxsports.com./soccer/boxscore?id=...        0    11
# 17  https://www.foxsports.com./soccer/boxscore?id=...        0    12
# 18  https://www.foxsports.com./soccer/boxscore?id=...        0    12
# 19  https://www.foxsports.com./soccer/boxscore?id=...        0    13
# 20  https://www.foxsports.com./soccer/boxscore?id=...        0    13
# 21  https://www.foxsports.com./soccer/boxscore?id=...        0    13
# 22  https://www.foxsports.com./soccer/boxscore?id=...        0    13
# 23  https://www.foxsports.com./soccer/boxscore?id=...        0    14
# 24  https://www.foxsports.com./soccer/boxscore?id=...        0    15
# 25  https://www.foxsports.com./soccer/boxscore?id=...        0    16
# 26  https://www.foxsports.com./soccer/boxscore?id=...        0    16
# 27  https://www.foxsports.com./soccer/boxscore?id=...        0    17
# 28  https://www.foxsports.com./soccer/boxscore?id=...        0    18
# 29  https://www.foxsports.com./soccer/boxscore?id=...        0    18
# 30  https://www.foxsports.com./soccer/boxscore?id=...        0    18
# 31  https://www.foxsports.com./soccer/boxscore?id=...        0    19
# 32  https://www.foxsports.com./soccer/boxscore?id=...        0    19
# 33  https://www.foxsports.com./soccer/boxscore?id=...        0    20
# 34  https://www.foxsports.com./soccer/boxscore?id=...        0    20
# 35  https://www.foxsports.com./soccer/boxscore?id=...        0    20
# 36  https://www.foxsports.com./soccer/boxscore?id=...        0    21
# 37  https://www.foxsports.com./soccer/boxscore?id=...        0    21
# 38  https://www.foxsports.com./soccer/boxscore?id=...        0    21
# 39  https://www.foxsports.com./soccer/boxscore?id=...        0    22
# 40  https://www.foxsports.com./soccer/boxscore?id=...        0    23
# 41  https://www.foxsports.com./soccer/boxscore?id=...        0    24
# 42  https://www.foxsports.com./soccer/boxscore?id=...        0    25
# 43  https://www.foxsports.com./soccer/boxscore?id=...        0    26
# 44  https://www.foxsports.com./soccer/boxscore?id=...        0    28
# 45  https://www.foxsports.com./soccer/boxscore?id=...        0    29
# 46  https://www.foxsports.com./soccer/boxscore?id=...        0    30
# 47  https://www.foxsports.com./soccer/boxscore?id=...        0    30
# 48  https://www.foxsports.com./soccer/boxscore?id=...        0    32
# 49  https://www.foxsports.com./soccer/boxscore?id=...        0    33
# 50  https://www.foxsports.com./soccer/boxscore?id=...        0    33
# 51  https://www.foxsports.com./soccer/boxscore?id=...        0    33
# 52  https://www.foxsports.com./soccer/boxscore?id=...        0    34
# 53  https://www.foxsports.com./soccer/boxscore?id=...        0    35
# 54  https://www.foxsports.com./soccer/boxscore?id=...        0    36
# 55  https://www.foxsports.com./soccer/boxscore?id=...        0    38
# 56  https://www.foxsports.com./soccer/boxscore?id=...        0    39
# 57  https://www.foxsports.com./soccer/boxscore?id=...        0    40
# 58  https://www.foxsports.com./soccer/boxscore?id=...        0    40
# 59  https://www.foxsports.com./soccer/boxscore?id=...        0    41
# 60  https://www.foxsports.com./soccer/boxscore?id=...        0    41
# 61  https://www.foxsports.com./soccer/boxscore?id=...        0    42
# 62  https://www.foxsports.com./soccer/boxscore?id=...        0    43
# 63  https://www.foxsports.com./soccer/boxscore?id=...        0    44
# 64  https://www.foxsports.com./soccer/boxscore?id=...        0    46
# 65  https://www.foxsports.com./soccer/boxscore?id=...        0    47
# 66  https://www.foxsports.com./soccer/boxscore?id=...        0    48
# 67  https://www.foxsports.com./soccer/boxscore?id=...        0    48
# 68  https://www.foxsports.com./soccer/boxscore?id=...        0    48
#
#                  team                                               comm
# 0       Bayern Munich                      The current period has begun.
# 1       Bayern Munich  Free kick for FC Bayern Munich in their own half.
# 2       Bayern Munich  Can FC Bayern Munich get the ball into an atta...
# 3       Bayern Munich  Harm Osmers signals a FC Bayern Munich throw-i...
# 4   Hertha BSC Berlin   Hertha BSC awarded a throw-in in their own half.
# 5       Bayern Munich  FC Bayern Munich's Thiago Alcantara gets in a ...
# 6   Hertha BSC Berlin       Harm Osmers awards the away team a throw-in.
# 7   Hertha BSC Berlin  A throw-in for the away team on the opposite h...
# 8       Bayern Munich   Throw-in for FC Bayern Munich in their own half.
# 9       Bayern Munich  FC Bayern Munich are coming forward and Thomas...
# 10  Hertha BSC Berlin         Goal kick for Hertha BSC at Allianz Arena.
# 11  Hertha BSC Berlin  Hertha BSC drives forward and Vedad Ibisevic g...
# 12  Hertha BSC Berlin  Harm Osmers signals a free kick to Hertha BSC ...
# 13  Hertha BSC Berlin  Hertha BSC to take a throw-in in FC Bayern Mun...
# 14  Hertha BSC Berlin                               Throw-in Hertha BSC.
# 15  Hertha BSC Berlin  Throw-in for Hertha BSC in the half of FC Baye...
# 16      Bayern Munich  The match at Allianz Arena has been interrupte...
# 17  Hertha BSC Berlin  Vedad Ibisevic for Hertha BSC gets in a strike...
# 18      Bayern Munich                 FC Bayern Munich have a goal kick.
# 19      Bayern Munich  FC Bayern Munich's Robert Lewandowski looks ok...
# 20      Bayern Munich  In Munich FC Bayern Munich drive forward throu...
# 21      Bayern Munich  Throw-in high up the field for FC Bayern Munic...
# 22  Hertha BSC Berlin          Throw-in for Hertha BSC at Allianz Arena.
# 23      Bayern Munich  Ball safe as FC Bayern Munich is awarded a thr...
# 24      Bayern Munich  Can FC Bayern Munich capitalize from this thro...
# 25      Bayern Munich                        Free kick FC Bayern Munich.
# 26  Hertha BSC Berlin  Vladimir Darida for Hertha BSC has been booked...
# 27      Bayern Munich  Thomas Muller for FC Bayern Munich drives towa...
# 28      Bayern Munich        FC Bayern Munich have a dangerous throw-in.
# 29      Bayern Munich                Corner awarded to FC Bayern Munich.
# 30      Bayern Munich  Throw-in for FC Bayern Munich close to the pen...
# 31  Hertha BSC Berlin         Throw-in for Hertha BSC in their own half.
# 32      Bayern Munich  Throw-in for FC Bayern Munich in the half of H...
# 33      Bayern Munich  FC Bayern Munich have been awarded a corner by...
# 34      Bayern Munich  Corentin Tolisso (FC Bayern Munich) wins the b...
# 35  Hertha BSC Berlin  Ball goes out of play for a Hertha BSC goal kick.
# 36  Hertha BSC Berlin  Hertha BSC awarded a free kick in their own half.
# 37      Bayern Munich    Throw-in for FC Bayern Munich at Allianz Arena.
# 38      Bayern Munich                Corner awarded to FC Bayern Munich.
# 39      Bayern Munich                         Throw-in FC Bayern Munich.
# 40      Bayern Munich  Goal! Robert Lewandowski gives FC Bayern Munic...
# 41      Bayern Munich  Serge Gnabry gets his shot on target but fails...
# 42  Hertha BSC Berlin        Free kick for Hertha BSC in their own half.
# 43      Bayern Munich  Ball safe as FC Bayern Munich is awarded a thr...
# 44  Hertha BSC Berlin  Harm Osmers signals a throw-in for Hertha BSC,...
# 45      Bayern Munich   Harm Osmers awards FC Bayern Munich a goal kick.
# 46      Bayern Munich  A throw-in for the home team on the opposite h...
# 47      Bayern Munich  Harm Osmers signals a free kick to FC Bayern M...
# 48      Bayern Munich      It's a goal kick for the home team in Munich.
# 49  Hertha BSC Berlin  FC Bayern Munich needs to be cautious. Hertha ...
# 50      Bayern Munich       Harm Osmers awards the home team a throw-in.
# 51  Hertha BSC Berlin  Hertha BSC to take a throw-in in FC Bayern Mun...
# 52      Bayern Munich  Throw-in high up the field for FC Bayern Munic...
# 53  Hertha BSC Berlin  Goal! The away team draw level at 1-1 through ...
# 54      Bayern Munich  Harm Osmers signals a free kick to FC Bayern M...
# 55  Hertha BSC Berlin  Marko Grujic scores to make it 1-2 at Allianz ...
# 56  Hertha BSC Berlin  Attention is being given to Hertha BSC’s Marko...
# 57  Hertha BSC Berlin         Goal kick for Hertha BSC at Allianz Arena.
# 58      Bayern Munich  Hertha BSC will need to be alert as they defen...
# 59  Hertha BSC Berlin  Hertha BSC's Marko Grujic is back in action af...
# 60  Hertha BSC Berlin      It's a goal kick for the away team in Munich.
# 61      Bayern Munich  FC Bayern Munich awarded a free kick in their ...
# 62      Bayern Munich  Can FC Bayern Munich capitalize from this thro...
# 63  Hertha BSC Berlin  Ball goes out of play for a Hertha BSC goal kick.
# 64      Bayern Munich  Free kick for FC Bayern Munich in the half of ...
# 65  Hertha BSC Berlin  Can Hertha BSC get the ball into an attacking ...
# 66      Bayern Munich  In Munich a free kick has been awarded the hom...
# 67      Bayern Munich  It's getting dangerous! Free kick for FC Bayer...
# 68  Hertha BSC Berlin                       Hertha BSC have a goal kick.

# %%
from sklearn.decomposition import LatentDirichletAllocation
